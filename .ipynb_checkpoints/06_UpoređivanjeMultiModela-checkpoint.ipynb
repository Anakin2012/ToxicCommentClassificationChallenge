# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import Image

# %%
# %run SharedFunctions.ipynb

# %% [markdown]
# Učitavaju se tabele sa izračunatim metrikama iz prethodnih sveski

# %%
report1 = pd.read_csv('data/report1.csv')
report2 = pd.read_csv('data/report2.csv')
report3 = pd.read_csv('data/report3.csv')

cr1 = pd.read_csv('data/cr1.csv')
cr2 = pd.read_csv('data/cr2.csv')
cr3 = pd.read_csv('data/cr3.csv')

# %%
report1.rename(columns={'Unnamed: 0': 'metrics'}, inplace=True)
report2.rename(columns={'Unnamed: 0': 'metrics'}, inplace=True)
report3.rename(columns={'Unnamed: 0': 'metrics'}, inplace=True)

# %%
# prvi model: tezine
report1
# Out:
#      metrics  toxic  severe_toxic  obscene  threat  insult  identity_hate
# 0  precision   0.96          0.37     0.79    0.27    0.71           0.39
# 1     recall   0.94          0.51     0.75    0.34    0.63           0.44
# 2         f1   0.95          0.43     0.77    0.30    0.67           0.41

# %%
# drugi model: augmentacija
report2
# Out:
#      metrics  toxic  severe_toxic  obscene  threat  insult  identity_hate
# 0  precision   0.96          0.41     0.80    0.39    0.69           0.48
# 1     recall   0.99          0.47     0.76    0.58    0.73           0.53
# 2         f1   0.97          0.44     0.78    0.47    0.71           0.50

# %%
# treci model: undersample
report3
# Out:
#      metrics  severe_toxic  obscene  threat  insult  identity_hate
# 0  precision          0.31     0.89    0.42    0.79           0.63
# 1     recall          0.60     0.87    0.47    0.88           0.56
# 2         f1          0.41     0.88    0.44    0.83           0.59

# %% [markdown]
# Prikaz matrica konfuzije za svaki od modela:

# %%
print('Model 1:')
Image('plots and images/confusion_matrix_multi.png')
# Out:
# Model 1:

# %%
print('Model 2:')
Image('plots and images/confusion_matrix_multi_aug.png')
# Out:
# Model 2:

# %%
print('Model 3:')
Image('plots and images/confusion_matrix_multi_without_toxic.png')
# Out:
# Model 3:

# %% [markdown]
# Metrika koja je bila najvažnija je odziv - što manji broj lažno negativnih. Lažno pozitivne su manje važne jer se klase svakako manje više preklapaju, pa i ako model svrsta komentar u još neku klasu pored tačnih nije veliki problem.

# %% [markdown]
# Proseci (macro, micro, weighted i samples)

# %%
print('Proseci metrika za prvi model')
cr1[6:]
# Out:
# Proseci metrika za prvi model
#      Unnamed: 0  precision  recall  f1-score  support
# 6     micro avg       0.79    0.78      0.79  17359.0
# 7     macro avg       0.58    0.60      0.59  17359.0
# 8  weighted avg       0.80    0.78      0.79  17359.0
# 9   samples avg       0.81    0.80      0.76  17359.0

# %%
print('Proseci metrika za drugi model')
cr2[6:]
# Out:
# Proseci metrika za drugi model
#      Unnamed: 0  precision  recall  f1-score  support
# 6     micro avg       0.81    0.81      0.81  19836.0
# 7     macro avg       0.63    0.63      0.62  19836.0
# 8  weighted avg       0.81    0.81      0.81  19836.0
# 9   samples avg       0.83    0.83      0.79  19836.0

# %%
print('Proseci metrika za treci model')
cr3[5:]
# Out:
# Proseci metrika za treci model
#      Unnamed: 0  precision  recall  f1-score  support
# 5     micro avg       0.77    0.80      0.78   9309.0
# 6     macro avg       0.62    0.69      0.64   9309.0
# 7  weighted avg       0.80    0.80      0.80   9309.0
# 8   samples avg       0.77    0.81      0.75   9309.0

# %%
prec_micro = np.array([cr1[6:7]['precision'].values[0], cr2[6:7]['precision'].values[0], cr3[5:6]['precision'].values[0]])
rec_micro = np.array([cr1[6:7]['recall'].values[0], cr2[6:7]['recall'].values[0], cr3[5:6]['recall'].values[0]])
f1_micro = np.array([cr1[6:7]['f1-score'].values[0], cr2[6:7]['f1-score'].values[0], cr3[5:6]['f1-score'].values[0]])
        
prec_macro = np.array([cr1[7:8]['precision'].values[0], cr2[7:8]['precision'].values[0], cr3[6:7]['precision'].values[0]])
rec_macro = np.array([cr1[7:8]['recall'].values[0], cr2[7:8]['recall'].values[0], cr3[6:7]['recall'].values[0]])
f1_macro = np.array([cr1[7:8]['f1-score'].values[0], cr2[7:8]['f1-score'].values[0], cr3[6:7]['f1-score'].values[0]])

# %%
X = ['Model1', 'Model2', 'Model3']

plt.figure(figsize=(18, 6))

plt.subplot(1, 2, 1)

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, prec_micro, 0.2, label = 'Precision', color = 'skyblue')
plt.bar(X_axis, rec_micro, 0.2, label = 'Recall', color = 'teal')
plt.bar(X_axis + 0.2 , f1_micro, 0.2, label = 'F1 score', color='pink')

plt.xticks(X_axis, X)
plt.title('Micro average')
plt.legend(loc='best')

plt.subplot(1, 2, 2)

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, prec_macro, 0.2, label = 'Precision', color = 'skyblue')
plt.bar(X_axis, rec_macro, 0.2, label = 'Recall', color = 'teal')
plt.bar(X_axis + 0.2 , f1_macro, 0.2, label = 'F1 score', color='pink')

plt.xticks(X_axis, X)
plt.title('Macro average')
plt.legend(loc='best')
  
plt.show()

# %% [markdown]
# Micro average (kada se uzima u obzir veličina klasa) je sličan za sva tri modela.
#
# Macro average se blago poboljšao augmentacijom, a ukljanjanje klase toxic je uticalo na poboljšanje makro proseka odziva.

# %% [markdown]
# Uporedićemo modele za svaku klasu pojedinačno:

# %%
models_toxic = [report1['toxic'], report2['toxic']]
models_severe = [report1['severe_toxic'], report2['severe_toxic'], report3['severe_toxic']]
models_obscene = [report1['obscene'], report2['obscene'], report3['obscene']]
models_threat = [report1['threat'], report2['threat'], report3['threat']]
models_insult = [report1['insult'], report2['insult'], report3['insult']]
models_identity = [report1['identity_hate'], report2['identity_hate'], report3['identity_hate']]

# %%
plot_metrics(models_toxic, 'toxic')

# %%
plot_metrics(models_severe, 'severe_toxic')

# %%
plot_metrics(models_obscene, 'obscene')

# %%
plot_metrics(models_threat, 'threat')

# %%
plot_metrics(models_insult, 'insult')

# %%
plot_metrics(models_identity, 'identity_hate')

# %% [markdown]
# ### Zaključak
#
# - multilabel modeli ne klasifikuju dobro, posebno na manje zastupljenim klasama
# - izbacivanje većinske klase toxic dovodi do većeg odziva kod manjinskih klasa
# - augmentacija je poboljšala odziv jedino za klasu threat
#     - poboljšanje: koristiti druge augmentatatore i veće količine augmentovanih podataka
# - klase insult, obscene i identity_hate najbolje se pogađaju kada se izbaci klasa toxic (model3)
#
# - teško je zaključiti kako se toksične klase preklapaju i po čemu se razlikuju, samim tim teško je tačno odrediti koje labele i koliko ih dodeliti određenom uvredljivom komentaru
