# %% [markdown]
# Balansiranje

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('../data/data_longer.csv')

# %%
data[data['target']==0].shape
# Out:
# (200985, 10)

# %%
data[data['target']==1].shape
# Out:
# (22468, 10)

# %%
clean = data[data['target']==0]
toxic = data[data['target']==1]

# %%
clean = clean[:22468]

# %%
new_data = pd.concat([clean, toxic])

# %%
new_data = new_data.sample(frac=1)

# %%
new_data.head()
# Out:
#         Unnamed: 0                                       comment_text  toxic  \
# 24127        24135  ability to vanish  such folks are only around ...      0
# 8855          8859  hi  its possible sounds like an interesting cl...      0
# 15528        15535  as you live in brum just thought id let you kn...      0
# 182307       54534  oh bitch is gonna block me better move to the ...      1
# 10990        10995  forget it man youre talking to a proxy anyway ...      0
#
#         severe_toxic  obscene  threat  insult  identity_hate  target  \
# 24127              0        0       0       0              0       0
# 8855               0        0       0       0              0       0
# 15528              0        0       0       0              0       0
# 182307             0        1       0       1              0       1
# 10990              0        0       0       0              0       0
#
#         word_count
# 24127           19
# 8855            23
# 15528           33
# 182307          14
# 10990           15

# %%
new_data.to_csv('../data/undersampled.csv')

# %%
new_data
# Out:
#         Unnamed: 0                                       comment_text  toxic  \
# 8947          8951  music and mathmatics   basically nobody cares ...      0
# 45182        45194  haha same old execuse from proi amperialistsi ...      0
# 3734          3735  this was resolved weeks ago with favor towards...      0
# 63075        63090  well its about ti ame that cj dub got blocked ...      1
# 176139       39821  you are so silly hayek couldnt use his term li...      1
# ...            ...                                                ...    ...
# 2195          2195  you are a fool if you think wikipedia is a res...      1
# 4447          4448  ok you delete the other two but not vezelis wh...      0
# 42425        42437  disputed fair use rationale for i amagemileywo...      0
# 20726        20734  hey ekograf its when you get a chance please c...      0
# 5250          5252     wikiproject article rescue squadron newsletter      0
#
#         severe_toxic  obscene  threat  insult  identity_hate  target  \
# 8947               0        0       0       0              0       0
# 45182              0        0       0       0              0       0
# 3734               0        0       0       0              0       0
# 63075              0        0       0       0              0       1
# 176139             0        0       0       1              0       1
# ...              ...      ...     ...     ...            ...     ...
# 2195               0        0       0       1              0       1
# 4447               0        0       0       0              0       0
# 42425              0        0       0       0              0       0
# 20726              0        0       0       0              0       0
# 5250               0        0       0       0              0       0
#
#         word_count
# 8947            24
# 45182           73
# 3734            56
# 63075           67
# 176139          27
# ...            ...
# 2195            17
# 4447            18
# 42425          156
# 20726           28
# 5250             5
#
# [66468 rows x 10 columns]
